# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df=pd.read_csv('news.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df.shape
# Out:
# (6335, 4)

# %%
data=df['text']

# %%
target=df.label

# %%
target
# Out:
# 0       FAKE
# 1       FAKE
# 2       REAL
# 3       FAKE
# 4       REAL
#         ...
# 6330    REAL
# 6331    FAKE
# 6332    FAKE
# 6333    REAL
# 6334    REAL
# Name: label, Length: 6335, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(data,target,train_size=0.8)

# %%
tfidf_vectorizer=TfidfVectorizer(stop_words='english',max_df=0.7)
tfidf_train=tfidf_vectorizer.fit_transform(x_train)
tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
tfidf_vectorizer.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
tfidf_vectorizer.vocabulary_
# Out:
# {'accepting': 1236,
#  'national': 21661,
#  'rifle': 27385,
#  'association': 2905,
#  'endorsement': 11153,
#  'week': 34848,
#  'donald': 10185,
#  'trump': 32908,
#  'warned': 34693,
#  'hillary': 15326,
#  'clinton': 6566,
#  'wants': 34660,
#  'abolish': 1138,
#  'second': 28531,
#  'amendment': 2111,
#  'cnn': 6651,
#  'corrected': 7757,
#  'noting': 22225,
#  'called': 5341,
#  'abolition': 1141,
#  '2nd': 565,
#  'technically': 31759,
#  'true': 32898,
#  'amounts': 2158,
#  'thing': 32083,
#  'interpreted': 16976,
#  'narrowly': 21630,
#  'imposes': 16209,
#  'practical': 24755,
#  'limits': 19060,
#  'gun': 14528,
#  'control': 7583,
#  'laws': 18641,
#  'interpretation': 16974,
#  'sure': 31224,
#  'guide': 14497,
#  'supreme': 31218,
#  'court': 7896,
#  'nominations': 22106,
#  'elected': 10852,
#  'president': 24951,
#  'day': 8597,
#  'addressed': 1459,
#  'nra': 22262,
#  'policy': 24493,
#  'advisers': 1600,
#  'told': 32373,
#  'bloomberg': 4354,
#  'politics': 24517,
#  'presumptive': 24978,
#  'democratic': 9024,
#  'presidential': 24952,
#  'nominee': 22107,
#  'disagrees': 9656,
#  'district': 10005,
#  'columbia': 6842,
#  'heller': 15137,
#  '2008': 406,
#  'decision': 8732,
#  'overturned': 23167,
#  'handgun': 14740,
#  'ban': 3464,
#  'adviser': 1599,
#  'maya': 20150,
#  'harris': 14871,
#  'said': 27958,
#  'believes': 3865,
#  'wrongly': 35415,
#  'decided': 8718,
#  'cities': 6389,
#  'states': 30466,
#  'power': 24730,
#  'craft': 7963,
#  'commonsense': 6962,
#  'residents': 27005,
#  'safe': 27938,
#  'case': 5647,
#  'explicitly': 11935,
#  'recognized': 26308,
#  'protects': 25355,
#  'individual': 16457,
#  'right': 27392,
#  'armed': 2686,
#  'self': 28621,
#  'defense': 8848,
#  'statement': 30463,
#  'roughly': 27670,
#  'equivalent': 11424,
#  'saying': 28205,
#  'roe': 27557,
#  'wade': 34563,
#  'protect': 25345,
#  'unborn': 33243,
#  'children': 6193,
#  'just': 17778,
#  'supporters': 31199,
#  'abortion': 1146,
#  'rights': 27401,
#  'justified': 17785,
#  'reading': 26128,
#  'rejection': 26640,
#  'position': 24653,
#  'theirs': 32016,
#  'confirms': 7241,
#  'hostility': 15650,
#  'glossing': 14025,
#  'details': 9329,
#  'law': 18628,
#  'strictest': 30806,
#  'kind': 18103,
#  'country': 7876,
#  'banned': 3510,
#  'handguns': 14741,
#  'popular': 24592,
#  'type': 33106,
#  'weapon': 34805,
#  'required': 26952,
#  'long': 19296,
#  'guns': 14538,
#  'disassembled': 9681,
#  'unloaded': 33606,
#  'disabled': 9644,
#  'trigger': 32805,
#  'lock': 19241,
#  'rule': 27779,
#  'impossible': 16213,
#  'use': 33909,
#  'shotguns': 29130,
#  'rifles': 27386,
#  'core': 7706,
#  'lawful': 18630,
#  'purpose': 25583,
#  'eminently': 11007,
#  'reasonable': 26178,
#  'storage': 30700,
#  'paradigmatic': 23395,
#  'example': 11743,
#  'possession': 24666,
#  'negated': 21783,
#  'wonder': 35247,
#  'candidate': 5423,
#  'claims': 6426,
#  'respect': 27049,
#  'intermittently': 16952,
#  'does': 10125,
#  'say': 28203,
#  'upheld': 33828,
#  'possibly': 24672,
#  'think': 32085,
#  'know': 18205,
#  'important': 16199,
#  'ownership': 23188,
#  'particularly': 23493,
#  'hunting': 15817,
#  'northeastern': 22182,
#  'pennsylvania': 23764,
#  'dunmore': 10512,
#  'month': 21147,
#  'regarding': 26529,
#  'agenda': 1695,
#  'responsible': 27070,
#  'owners': 23187,
#  'stand': 30400,
#  'sport': 30207,
#  'shooting': 29094,
#  'collecting': 6779,
#  'conspicuously': 7395,
#  'absent': 1168,
#  'list': 19123,
#  'legitimate': 18792,
#  'things': 32084,
#  'people': 23780,
#  'australian': 3104,
#  'government': 14165,
#  'mass': 20043,
#  'confiscations': 7246,
#  'firearms': 12694,
#  'admires': 1520,
#  'takes': 31574,
#  'similar': 29331,
#  'view': 34300,
#  'australians': 3105,
#  'demonstrate': 9056,
#  'genuine': 13785,
#  'reason': 26177,
#  'owning': 23189,
#  'personal': 23900,
#  'protection': 25348,
#  'count': 7842,
#  'australia': 3103,
#  'campaign': 5380,
#  'website': 34830,
#  'mentions': 20444,
#  'dozen': 10306,
#  'times': 32274,
#  'compared': 7000,
#  '800': 934,
#  'site': 29422,
#  'context': 7514,
#  'references': 26457,
#  'criticize': 8106,
#  'taking': 31576,
#  'seriously': 28748,
#  'oregon': 22840,
#  'fall': 12183,
#  'instance': 16788,
#  'rejected': 26638,
#  'single': 29378,
#  'minded': 20723,
#  'absolutist': 1173,
#  'theology': 32034,
#  'sacrosanct': 27918,
#  'constitutional': 7426,
#  'tailored': 31554,
#  'appropriate': 2547,
#  'way': 34772,
#  'breaching': 4776,
#  'constitution': 7425,
#  'actually': 1412,
#  'breach': 4773,
#  'restrictions': 27101,
#  'speech': 30088,
#  'serve': 28757,
#  'compelling': 7014,
#  'trim': 32814,
#  'fit': 12745,
#  'make': 19678,
#  'voting': 34516,
#  'issue': 17270,
#  'says': 28206,
#  'agree': 1735,
#  'republican': 26929,
#  'claim': 6423,
#  'election': 10854,
#  'rigged': 27390,
#  'represents': 26902,
#  'outlandish': 22980,
#  'moment': 21062,
#  'devoted': 9437,
#  'dismantling': 9832,
#  'political': 24505,
#  'norms': 22177,
#  'feel': 12428,
#  'nefarious': 21779,
#  'forces': 13042,
#  'moving': 21321,
#  'white': 34987,
#  'house': 15674,
#  'elections': 10855,
#  'occasionally': 22487,
#  'disputed': 9903,
#  'votes': 34513,
#  'counted': 7844,
#  'marred': 19967,
#  'accusations': 1304,
#  'dark': 8533,
#  'instruments': 16826,
#  'fraud': 13252,
#  'dead': 8619,
#  'casting': 5673,
#  'weeks': 34855,
#  'voters': 34512,
#  'going': 14082,
#  'polls': 24529,
#  'race': 25812,
#  'deliberately': 8956,
#  'stacked': 30334,
#  'fearful': 12382,
#  'establishment': 11562,
#  'flies': 12861,
#  'face': 12088,
#  'historical': 15385,
#  'precedent': 24806,
#  'lose': 19351,
#  'threatens': 32141,
#  'legitimacy': 18791,
#  'left': 18751,
#  'govern': 14161,
#  'anarchic': 2203,
#  'modern': 21002,
#  'history': 15390,
#  'remember': 26739,
#  'competing': 7026,
#  'wisconsin': 35162,
#  'rally': 25930,
#  'monday': 21081,
#  'night': 22011,
#  'want': 34656,
#  'try': 32961,
#  'rig': 27388,
#  'polling': 24528,
#  'booths': 4562,
#  'corrupt': 7788,
#  'voter': 34511,
#  'common': 6957,
#  'experts': 11918,
#  'inflict': 16568,
#  'standing': 30406,
#  'damage': 8464,
#  'eroding': 11480,
#  'trust': 32938,
#  'probity': 25109,
#  'electoral': 10858,
#  'process': 25121,
#  'weary': 34815,
#  'george': 13804,
#  'washington': 34728,
#  'rode': 27546,
#  'home': 15489,
#  'mount': 21276,
#  'vernon': 34201,
#  '1797': 203,
#  'american': 2118,
#  'democracy': 9021,
#  'rested': 27082,
#  'cherished': 6141,
#  'principle': 25054,
#  'transfer': 32640,
#  'outgoing': 22975,
#  'successor': 31027,
#  'widely': 35030,
#  'seen': 28579,
#  'winners': 35136,
#  'win': 35103,
#  'losers': 19353,
#  'mark': 19933,
#  'braden': 4708,
#  'chief': 6180,
#  'counsel': 7837,
#  'committee': 6951,
#  'rational': 26054,
#  'support': 31196,
#  'loser': 19352,
#  'winner': 35135,
#  'won': 35246,
#  'gop': 14129,
#  'primary': 25040,
#  'rivals': 27462,
#  'florida': 12897,
#  'sen': 28663,
#  'marco': 19878,
#  'rubio': 27748,
#  'come': 6872,
#  'slips': 29596,
#  'democrat': 9023,
#  'prompting': 25260,
#  'deal': 8633,
#  'conspiratorial': 7400,
#  'shield': 29013,
#  'culpability': 8266,
#  'fate': 12312,
#  'sign': 29283,
#  'loyal': 19405,
#  'accept': 1232,
#  'warnings': 34697,
#  'horror': 15624,
#  'place': 24251,
#  'stolen': 30675,
#  'swaying': 31359,
#  'john': 17609,
#  'kennedy': 17977,
#  'henchmen': 15181,
#  'allegedly': 1955,
#  'cheating': 6082,
#  'richard': 27340,
#  'nixon': 22059,
#  'presidency': 24950,
#  '1960': 330,
#  'infamous': 16520,
#  'hanging': 14771,
#  'chads': 5914,
#  'recount': 26349,
#  '2000': 396,
#  'repeated': 26847,
#  'nuclear': 22279,
#  'option': 22798,
#  'essentially': 11553,
#  'advance': 1564,
#  'illegitimate': 16030,
#  'challenging': 5957,
#  'results': 27116,
#  'signs': 29306,
#  'wrongdoing': 35410,
#  'replete': 26873,
#  'illegal': 16024,
#  'point': 24451,
#  '21st': 453,
#  'century': 5872,
#  'grandiose': 14235,
#  'like': 19024,
#  'bogus': 4448,
#  'anti': 2367,
#  'spirit': 30153,
#  'historian': 15382,
#  'douglas': 10258,
#  'brinkley': 4885,
#  'rice': 27338,
#  'university': 33579,
#  'new': 21910,
#  'ohio': 22598,
#  'secretary': 28541,
#  'state': 30457,
#  'jon': 17640,
#  'husted': 15845,
#  'carol': 5592,
#  'costello': 7810,
#  'makes': 19682,
#  'easy': 10656,
#  'vote': 34508,
#  'hard': 14820,
#  'cheat': 6080,
#  'assure': 2918,
#  'charge': 6026,
#  'll': 19189,
#  'warning': 34696,
#  'claimed': 6424,
#  'used': 33910,
#  'idea': 15937,
#  'followers': 12989,
#  'persecuted': 23881,
#  'device': 9422,
#  'motivate': 21252,
#  'base': 3614,
#  'returned': 27195,
#  'theme': 32020,
#  'venomous': 34160,
#  'rigging': 27391,
#  'west': 34917,
#  'palm': 23309,
#  'beach': 3717,
#  'thursday': 32192,
#  'media': 20296,
#  'step': 30579,
#  'global': 13999,
#  'conspiracy': 7398,
#  'elites': 10910,
#  'hit': 15394,
#  'intensity': 16888,
#  'late': 18566,
#  'weekend': 34850,
#  'absolutely': 1171,
#  'dishonest': 9800,
#  'distorted': 9981,
#  'pushing': 25606,
#  'crooked': 8127,
#  'places': 24257,
#  'sad': 27919,
#  'tweeted': 33074,
#  'sunday': 31121,
#  'course': 7893,
#  'large': 18533,
#  'scale': 28217,
#  'happening': 14793,
#  'leaders': 18676,
#  'deny': 9126,
#  'naive': 21579,
#  'added': 1440,
#  'raised': 25910,
#  'doubts': 10256,
#  'integrity': 16865,
#  'crucial': 8169,
#  'swing': 31395,
#  'urged': 33882,
#  'ensure': 11282,
#  'perpetrated': 23865,
#  'order': 22831,
#  'appears': 2490,
#  'risk': 27443,
#  'intimidation': 17022,
#  'ally': 1998,
#  'rudolph': 27764,
#  'giuliani': 13943,
#  'mayor': 20160,
#  'york': 35605,
#  'city': 6397,
#  'union': 33551,
#  'moron': 21199,
#  'assume': 2910,
#  'run': 27801,
#  'philadelphia': 24023,
#  'chicago': 6169,
#  'actual': 1406,
#  'evidence': 11692,
#  '2016': 418,
#  'billionaire': 4121,
#  'certainly': 5888,
#  'provided': 25391,
#  'suggesting': 31068,
#  'massive': 20055,
#  'unknown': 33588,
#  'corruption': 7791,
#  '19th': 377,
#  'controversies': 7590,
#  'contested': 7511,
#  'congress': 7290,
#  '1824': 223,
#  'princeton': 25051,
#  'professor': 25173,
#  'julian': 17733,
#  'zelizer': 35715,
#  'referring': 26462,
#  'ultimately': 33175,
#  'representatives': 26899,
#  'awarded': 3211,
#  'quincy': 25760,
#  'adams': 1426,
#  'candidates': 5424,
#  'majority': 19677,
#  'virtually': 34382,
#  'entire': 11314,
#  'decentralized': 8710,
#  'fragmented': 13205,
#  'little': 19158,
#  'happen': 14791,
#  'recent': 26264,
#  'academic': 1213,
#  'studies': 30871,
#  'shown': 29162,
#  'infinitesimal': 16552,
#  'levels': 18898,
#  'despite': 9298,
#  'republicans': 26931,
#  'widespread': 35035,
#  'effort': 10772,
#  'liberals': 18947,
#  'restrict': 27097,
#  'poll': 24523,
#  'access': 1239,
#  'disproportionately': 9897,
#  'disqualify': 9909,
#  'minority': 20768,
#  'tend': 31849,
#  'democrats': 9029,
#  'pressure': 24962,
#  'rising': 27442,
#  'key': 17998,
#  'repudiate': 26935,
#  'speaker': 30033,
#  'paul': 23617,
#  'ryan': 27860,
#  'released': 26674,
#  'spokeswoman': 30193,
#  'saturday': 28151,
#  'fully': 13435,
#  'confident': 7228,
#  'carry': 5614,
#  'senate': 28666,
#  'leader': 18674,
#  'mitch': 20927,
#  'mcconnell': 20197,
#  'spoken': 30188,
#  'person': 23896,
#  'officials': 22571,
#  'systems': 31492,
#  'iowa': 17142,
#  'north': 22180,
#  'carolina': 5593,
#  'turn': 33039,
#  'blind': 4300,
#  'eye': 12052,
#  'conduct': 7202,
#  'designed': 9271,
#  'party': 23517,
#  'participate': 23484,
#  'doing': 10136,
#  'running': 27807,
#  'mate': 20078,
#  'indiana': 16414,
#  'gov': 14158,
#  'mike': 20643,
#  'pence': 23745,
#  'appeared': 2488,
#  'split': 30175,
#  'partner': 23508,
#  'nbc': 21722,
#  'meet': 20336,
#  'press': 24956,
#  'suggested': 31067,
#  'irregularities': 17185,
#  'real': 26138,
#  'problem': 25110,
#  'embraced': 10981,
#  'notion': 22226,
#  'elite': 10909,
#  'extension': 11994,
#  'hoodwinking': 15560,
#  'given': 13947,
#  'branded': 4740,
#  'business': 5192,
#  'life': 18988,
#  'ultimate': 33174,
#  'prospect': 25329,
#  'crushing': 8205,
#  'defeat': 8822,
#  'november': 22249,
#  'grandest': 14230,
#  'stage': 30349,
#  'bitter': 4205,
#  'pre': 24791,
#  'spinning': 30146,
#  'possible': 24670,
#  'represent': 26895,
#  'saving': 28184,
#  'hedging': 15095,
#  'loss': 19356,
#  'jessica': 17528,
#  'lavariega': 18621,
#  'monforti': 21091,
#  'chair': 5931,
#  'department': 9133,
#  'pace': 23217,
#  'close': 6593,
#  'likely': 19029,
#  'laying': 18654,
#  'groundwork': 14418,
#  'legal': 18762,
#  'challenge': 5952,
#  'depends': 9148,
#  'pulls': 25500,
#  'victory': 34286,
#  'presumably': 24972,
#  'withdraw': 35186,
#  'product': 25149,
#  'charges': 6028,
#  'prompt': 25258,
#  'americans': 2121,
#  'thoughts': 32126,
#  'choose': 6249,
#  'line': 19072,
#  'dying': 10574,
#  'moments': 21065,
#  'plenty': 24359,
#  'examples': 11744,
#  'look': 19310,
#  'chose': 6265,
#  'result': 27112,
#  'advisors': 1604,
#  'wanted': 34657,
#  'reasoning': 26181,
#  'future': 13501,
#  'nation': 21660,
#  'senator': 28667,
#  'trend': 32754,
#  'continue': 7529,
#  'wholehearted': 35008,
#  'closed': 6594,
#  'hope': 15577,
#  'claiming': 6425,
#  'college': 6791,
#  'fight': 12585,
#  'vice': 34264,
#  'al': 1849,
#  'gore': 14136,
#  'conceded': 7123,
#  'bush': 5186,
#  'grace': 14188,
#  'half': 14669,
#  'ago': 1730,
#  'stephen': 30583,
#  'abraham': 1154,
#  'lincoln': 19066,
#  'defeated': 8824,
#  'partisan': 23500,
#  'feeling': 12429,
#  'yield': 35577,
#  'patriotism': 23595,
#  'mr': 21335,
#  'god': 14060,
#  'bless': 4292,
#  'elect': 10849,
#  'remains': 26726,
#  'rancor': 25962,
#  'aside': 2812,
#  'stewardship': 30605,
#  'question': 25731,
#  'deeply': 8809,
#  'rancorous': 25963,
#  'cleaved': 6513,
#  'divides': 10049,
#  'deeper': 8806,
#  'summon': 31113,
#  'words': 35286,
#  'tuesday': 32986,
#  'elizabeth': 10914,
#  'warren': 34709,
#  'declared': 8745,
#  'ready': 26131,
#  'massachusetts': 20044,
#  'progressive': 25203,
#  'wing': 35124,
#  'declaration': 8741,
#  'shortly': 29123,
#  'endorsing': 11158,
#  'calling': 5344,
#  'fighter': 12587,
#  'guts': 14558,
#  'interview': 17007,
#  'msnbc': 21344,
#  'asked': 2819,
#  'rachel': 25817,
#  'maddow': 19576,
#  'believe': 3861,
#  'boston': 4606,
#  'globe': 14011,
#  'endorsed': 11152,
#  'jump': 17741,
#  'united': 33562,
#  'gets': 13847,
#  'near': 21740,
#  'according': 1278,
#  'praised': 24775,
#  'opponent': 22758,
#  'bernie': 3978,
#  'sanders': 28061,
#  'incredible': 16372,
#  'speaking': 30037,
#  'evening': 11668,
#  'powerfully': 24735,
#  'ran': 25957,
#  'heart': 15042,
#  'took': 32413,
#  'issues': 17273,
#  'really': 26158,
#  'thrust': 32172,
#  'spotlight': 30212,
#  'dear': 8644,
#  'brought': 4960,
#  'millions': 20698,
#  'tough': 32497,
#  'need': 21762,
#  'came': 5367,
#  'hours': 15673,
#  'barack': 3524,
#  'obama': 22380,
#  'formally': 13110,
#  'giving': 13950,
#  'candidacy': 5422,
#  'video': 34289,
#  'recorded': 26342,
#  'don': 10183,
#  'qualified': 25685,
#  'hold': 15453,
#  'office': 22563,
#  'joe': 17606,
#  'biden': 4077,
#  'willing': 35091,
#  'favourite': 12350,
#  'taught': 31701,
#  'harvard': 14885,
#  'help': 15156,
#  'entice': 11313,
#  'disaffected': 9649,
#  'excited': 11780,
#  'ambivalent': 2094,
#  'especially': 11534,
#  'fierce': 12574,
#  'recently': 26265,
#  'criticism': 8104,
#  'attacking': 3011,
#  'searing': 28511,
#  'string': 30816,
#  'speeches': 30089,
#  'setting': 28790,
#  'prominent': 25239,
#  'pugilistic': 25489,
#  'role': 27568,
#  'ticket': 32215,
#  'earlier': 10617,
#  'society': 29813,
#  'dc': 8609,
#  'businessman': 5195,
#  'inherited': 16640,
#  'fortune': 13140,
#  'kept': 17987,
#  'rolling': 27574,
#  'described': 9249,
#  'loud': 19368,
#  'nasty': 21647,
#  'skinned': 29485,
#  'serves': 28761,
#  'attacks': 3012,
#  'gonzalo': 14108,
#  'curiel': 8314,
#  'federal': 12407,
#  'judge': 17710,
#  'presiding': 24954,
#  'suit': 31080,
#  'exactly': 11728,
#  'expect': 11875,
#  'somebody': 29892,
#  'racist': 25824,
#  'bully': 5098,
#  'appropriations': 2551,
#  'hearing': 15038,
#  'lawmakers': 18635,
#  'language': 18508,
#  'spending': 30110,
#  'stating': 30479,
#  'duty': 10553,
#  'debate': 8657,
#  'determine': 9358,
#  'authorize': 3128,
#  'military': 20674,
#  'force': 13037,
#  'islamic': 17230,
#  'iraq': 17157,
#  'syria': 31482,
#  'known': 18211,
#  'isil': 17223,
#  'isis': 17224,
#  'offered': 22559,
#  'rep': 26827,
#  'barbara': 3532,
#  'lee': 18743,
#  'calif': 5331,
#  'binding': 4138,
#  'effect': 10759,
#  'congressional': 7292,
#  'duration': 10531,
#  'costs': 7813,
#  'endgame': 11139,
#  'war': 34665,
#  'simply': 29356,
#  'responsibility': 27069,
#  'recognize': 26307,
#  'play': 24317,
#  'matters': 20113,
#  'peace': 23675,
#  'past': 23544,
#  'time': 32268,
#  'reassert': 26184,
#  'making': 19687,
#  'allow': 1985,
#  'endless': 11142,
#  'job': 17597,
#  'requires': 26955,
#  'directing': 9625,
#  'airstrikes': 1822,
#  'august': 3085,
#  'authorization': 3126,
#  'declare': 8744,
#  'wars': 34715,
#  'doesn': 10126,
#  'sweeping': 31370,
#  '2001': 398,
#  'covers': 7918,
#  'actions': 1387,
#  'months': 21150,
#  'sent': 28699,
#  'specific': 30059,
#  'aumf': 3088,
#  'proposal': 25298,
#  'february': 12402,
#  'welcomed': 34890,
#  'needs': 21774,
#  'broad': 4905,
#  'restrictive': 27102,
#  'differences': 9523,
#  'complacency': 7038,
#  'leaves': 18727,
#  'engaged': 11195,
#  'end': 11125,
#  'sight': 29277,
#  'spent': 30113,
#  'billion': 4120,
#  'participated': 23485,
#  '000': 1,
#  'personnel': 23910,
#  'reality': 26151,
#  'fear': 12380,
#  'goes': 14075,
#  'wrong': 35407,
#  'fingerprints': 12672,
#  'handful': 14739,
#  'priority': 25071,
#  'showed': 29155,
#  'bipartisan': 4169,
#  'debating': 8662,
#  'boehner': 4435,
#  'signaled': 29286,
#  'isn': 17248,
#  'watch': 34743,
#  'evading': 11650,
#  'sides': 29253,
#  'aisle': 1827,
#  'quite': 25776,
#  'frankly': 13240,
#  'handing': 14745,
#  'authority': 3125,
#  'executive': 11808,
#  'branch': 4734,
#  'presidents': 24953,
#  'hands': 14758,
#  'gigantic': 13897,
#  'mistake': 20903,
#  'cole': 6757,
#  'rodney': 27550,
#  'frelinghuysen': 13298,
#  'opposed': 22766,
#  'totally': 32482,
#  'inappropriate': 16269,
#  'tie': 32226,
#  'measure': 20272,
#  'amendments': 2112,
#  'repealed': 26843,
#  'cushion': 8349,
#  'pass': 23522,
#  '2002': 400,
#  'authorized': 3129,
#  'aumfs': 3089,
#  'expiration': 11919,
#  'date': 8565,
#  'leaned': 18699,
#  'justification': 17783,
#  'action': 1382,
#  'ted': 31771,
#  'cruz': 8209,
#  'developed': 9408,
#  'reputation': 26945,
#  'conservative': 7359,
#  'major': 19675,
#  'hasn': 14906,
#  'taken': 31570,
#  'positions': 24656,
#  'earn': 10621,
#  'moniker': 21101,
#  'exception': 11759,
#  'longtime': 19308,
#  'flat': 12812,
#  'tax': 31712,
#  'dramatically': 10333,
#  'lowers': 19399,
#  'rate': 26040,
#  'exempts': 11817,
#  'capital': 5473,
#  'gains': 13550,
#  'dividends': 10047,
#  'taxation': 31714,
#  'astonishingly': 2929,
#  'regressive': 26562,
#  'rich': 27339,
#  'pay': 23644,
#  'far': 12249,
#  'hedge': 15091,
#  'fund': 13453,
#  'managers': 19752,
#  'private': 25081,
#  'equity': 11422,
#  'types': 33108,
#  'mitt': 20935,
#  'romney': 27591,
#  'literally': 19140,
#  'exact': 11727,
#  'varies': 34082,
#  'plan': 24274,
#  'low': 19393,
#  '10': 50,
#  '15': 146,
#  'percent': 23793,
#  'meaning': 20259,
#  'raise': 25909,
#  'taxes': 31716,
#  'middle': 20609,
#  'class': 6463,
#  'currently': 8326,
#  'brackets': 4706,
#  'drives': 10392,
#  'crazy': 8000,
#  'fiscal': 12730,
#  'fantasy': 12247,
#  'wish': 35168,
#  'existed': 11843,
#  'did': 9506,
#  'fdr': 12377,
#  'writes': 35401,
#  'wonkblog': 35257,
#  'matt': 20108,
#  'brien': 4863,
#  'interested': 16924,
#  'governing': 14164,
#  'today': 32357,
#  'ideas': 15945,
#  'monomaniacal': 21118,
#  'obsession': 22453,
#  'growth': 14434,
#  'disaster': 9682,
#  'progressivity': 25209,
#  'anchor': 2216,
#  'thinking': 32090,
#  'crazily': 7998,
#  'benefits': 3927,
#  'economy': 10699,
#  'substantially': 30984,
#  'better': 4017,
#  'plans': 24286,
#  'politicians': 24508,
#  'promote': 25249,
#  'ask': 2816,
#  'alcohol': 1879,
#  'carbon': 5521,
#  ...}

# %%
tfidf_vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000000031',
#  '00000031',
#  '0001',
#  '0002',
#  '000billion',
#  '000x',
#  '001',
#  '002',
#  '003',
#  '007',
#  '008',
#  '009',
#  '01',
#  '010',
#  '013c2812c9',
#  '02',
#  '022',
#  '027',
#  '028',
#  '03',
#  '0325',
#  '033',
#  '035',
#  '03eb',
#  '04',
#  '049',
#  '05',
#  '06',
#  '07',
#  '071',
#  '075',
#  '0750',
#  '079',
#  '07dryempjx',
#  '08',
#  '080',
#  '084',
#  '0851',
#  '09',
#  '098263',
#  '09pm',
#  '0_65b67362bd',
#  '0_jgdktlmn',
#  '0fjjvowyhg8qtskiz',
#  '0h4at2yetra17uxetni02ls2jeg0mty45jrcu7mrzsrpcbq464i',
#  '0t5',
#  '0txrbwvobzz4fi5nksw6k5a6cxzbb3juxthmdiz93cby8gvrqiypzhajvjnt2',
#  '0x',
#  '10',
#  '100',
#  '1000',
#  '10000s',
#  '1001',
#  '100k',
#  '100percentfedup',
#  '100th',
#  '101',
#  '101st',
#  '102',
#  '102816',
#  '103',
#  '104',
#  '1040s',
#  '105',
#  '106',
#  '107',
#  '1070',
#  '108',
#  '109',
#  '10m54s',
#  '10pm',
#  '10s',
#  '10th',
#  '10yrs',
#  '11',
#  '110',
#  '1100',
#  '1100s',
#  '1105',
#  '112',
#  '1121',
#  '112145924',
#  '113',
#  '114',
#  '114th',
#  '115',
#  '115th',
#  '116',
#  '11702',
#  '118',
#  '119',
#  '1190',
#  '11am',
#  '11cm',
#  '11pm',
#  '11th',
#  '12',
#  '120',
#  '1207',
#  '122',
#  '123',
#  '12333',
#  '124',
#  '125',
#  '1261',
#  '1265',
#  '127',
#  '128',
#  '129',
#  '12hdlgeeua87t2ju8m4tbro247yj5u2tvp',
#  '12k',
#  '12pm',
#  '12sso1zj2bbdguiraddmamlnets7oc1',
#  '12t',
#  '12th',
#  '13',
#  '130',
#  '1305',
#  '130500',
#  '131',
#  '133',
#  '134',
#  '135',
#  '13603',
#  '137',
#  '138',
#  '139',
#  '1393',
#  '13th',
#  '14',
#  '140',
#  '1400s',
#  '1401',
#  '141',
#  '142',
#  '143',
#  '144',
#  '14474',
#  '146',
#  '147',
#  '14774',
#  '148',
#  '149',
#  '14th',
#  '15',
#  '150',
#  '1500s',
#  '151',
#  '1513',
#  '152',
#  '1538',
#  '155',
#  '1552',
#  '1559',
#  '156',
#  '1562',
#  '1563',
#  '1566',
#  '1569',
#  '1576',
#  '1578',
#  '158',
#  '1584',
#  '159',
#  '15bn',
#  '15s',
#  '15th',
#  '15yrs',
#  '16',
#  '160',
#  '1600',
#  '161',
#  '1610',
#  '1612',
#  '162lvbnkan',
#  '163',
#  '164',
#  '165',
#  '1650',
#  '166',
#  '167',
#  '1689',
#  '169',
#  '16s',
#  '16th',
#  '17',
#  '170',
#  '1700',
#  '171',
#  '1711',
#  '172',
#  '1720',
#  '173',
#  '175',
#  '178',
#  '1786',
#  '1787',
#  '1789',
#  '179',
#  '1793',
#  '1793qianlong',
#  '1797',
#  '1799',
#  '17k',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '1800s',
#  '1801',
#  '1806',
#  '181',
#  '1812',
#  '1815',
#  '1816',
#  '1817',
#  '1818',
#  '182',
#  '1820',
#  '1820s',
#  '1823',
#  '1824',
#  '1825',
#  '1829',
#  '183',
#  '1830',
#  '1830s',
#  '1831',
#  '1835',
#  '1837',
#  '184',
#  '1841',
#  '1845',
#  '1848',
#  '1849',
#  '185',
#  '1850',
#  '1850s',
#  '1851',
#  '1853',
#  '1854',
#  '1857',
#  '1858',
#  '1859',
#  '186',
#  '1864',
#  '1868',
#  '187',
#  '1870s',
#  '1871',
#  '1873',
#  '1876',
#  '1877',
#  '1878',
#  '1880',
#  '1881',
#  '1883',
#  '1886',
#  '1887',
#  '189',
#  '1892',
#  '1893',
#  '1895',
#  '1896',
#  '1898',
#  '18f',
#  '18th',
#  '19',
#  '190',
#  '1900',
#  '1900s',
#  '1901',
#  '1903',
#  '1904',
#  '1905',
#  '1907',
#  '1908',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1917',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1920s',
#  '1921',
#  '1922',
#  '1924',
#  '1925',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1930s',
#  '1931',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '1940',
#  '1940s',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1950s',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '196',
#  '1960',
#  '1960s',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '198974609375',
#  '199',
#  '1990',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19m',
#  '19th',
#  '1alvwe4bralkh',
#  '1ao',
#  '1bbswheiehlqifxzus3j35',
#  '1bjxt3uhim5fqn93gb0hkxakuarz99d7xcitzftye',
#  '1bn',
#  '1hztlj',
#  '1is9krdfnysv0buhf8elizydmsrpwn944flw1tofjw46j4uaxsbrbp284wifmv8n',
#  '1k',
#  '1m08s',
#  '1mgfbvy',
#  '1million',
#  '1mwvcarc3jsuon8rrxype4espweqzd6zsrbhgh4uqf56pcft2ubnqku4wtgoecsw',
#  '1st',
#  '1vwbsd9c79',
#  '1wrwsaijjsohk5rzj',
#  '1z',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '20017',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200bln',
#  '200k',
#  '200x',
#  '201',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2024',
#  '2025',
#  '2040',
#  '2048',
#  '205',
#  '2050',
#  '20535',
#  '206',
#  '2064',
#  '207',
#  '209',
#  '20am',
#  '20book',
#  '20gs',
#  '20k',
#  '20power',
#  '20s',
#  '20th',
#  '21',
#  '211',
#  '212',
#  '213',
#  '2149237058061490',
#  '214r',
#  '215',
#  '2160',
#  '217',
#  '218',
#  '21st',
#  '21wire',
#  '22',
#  '220',
#  '221day_m25',
#  '222',
#  '223',
#  '2235360',
#  '224',
#  '225',
#  '226t',
#  '227',
#  '228',
#  '229',
#  '22autoupdate',
#  '22basemap',
#  '22default',
#  '22event',
#  '22feed',
#  '22grayscale',
#  '22list',
#  '22listformat',
#  '22map',
#  '22mapposition',
#  '22nd',
#  '22newest',
#  '22overlays',
#  '22plates',
#  '22restrictlisttomap',
#  '22search',
#  '22sort',
#  '22timezone',
#  '22us1000778i',
#  '22utc',
#  '22viewmodes',
#  '23',
#  '230',
#  '231',
#  '232',
#  '233',
#  '234',
#  '235',
#  '236',
#  '237',
#  '23k',
#  '23rd',
#  '24',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244th',
#  '245',
#  '24th',
#  '25',
#  '250',
#  '2513',
#  '252',
#  '253207',
#  '2544',
#  '256',
#  '257',
#  '258',
#  '25m',
#  '25th',
#  '26',
#  '260',
#  '261',
#  '262',
#  '263',
#  '264',
#  '265',
#  '2670',
#  '268',
#  '269',
#  '26th',
#  '27',
#  '270',
#  '2700',
#  '272',
#  '273',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '27th',
#  '28',
#  '280',
#  '281',
#  '282',
#  '284',
#  '288',
#  '289',
#  '28th',
#  '29',
#  '290',
#  '292',
#  '293',
#  '297',
#  '29th',
#  '2c',
#  '2ccrww3wqeay',
#  '2ckus9qi9g',
#  '2cs',
#  '2gary2',
#  '2gkhtimovh',
#  '2hibftjxscml3k8k6mbdi8p9zvcmjsxbppcyrffw9a6t',
#  '2k',
#  '2kkpwafd9pxaqnwjmpd4amk60l3n',
#  '2l',
#  '2m52s',
#  '2nd',
#  '2plwa3cerym6byp60362co7cpzochyhsvgppzyh0qex',
#  '2yxlvcf03qflflgzzfn7fcv5jw',
#  '2zksz3xesc7mmpgrzanh4pk1dlr',
#  '30',
#  '300',
#  '3000',
#  '302',
#  '304',
#  '307',
#  '307th',
#  '308',
#  '30am',
#  '30grams',
#  '30k',
#  '30mki',
#  '30s',
#  '30sm',
#  '30th',
#  '30th_in',
#  '31',
#  '310',
#  '313',
#  '316',
#  '317',
#  '318',
#  '31st',
#  '32',
#  '320',
#  '3200',
#  '328',
#  '33',
#  '330',
#  '331',
#  '332',
#  '333',
#  '334',
#  '33rd',
#  '33yo',
#  '34',
#  '340',
#  '343',
#  '346',
#  '347',
#  '348',
#  '349',
#  '35',
#  '350',
#  '350s',
#  '3515',
#  '352',
#  '353',
#  '3540',
#  '356',
#  '357',
#  '3570',
#  '36',
#  '360',
#  '362',
#  '363',
#  '365',
#  '367',
#  '368',
#  '36th',
#  '37',
#  '370',
#  '3700',
#  '374',
#  '375cl78e5v',
#  '3776',
#  '378',
#  '379',
#  '38',
#  '380',
#  '382',
#  '383',
#  '383rd',
#  '384',
#  '385',
#  '386',
#  '389',
#  '39',
#  '390',
#  '3900',
#  '395k',
#  '39th',
#  '3a',
#  '3am',
#  '3anull',
#  '3fm',
#  '3grlcqvbjh',
#  '3m',
#  '3oizbynytffvowy2zbh3h2pgf',
#  '3rd',
#  '3s',
#  '3w75pamy52nazi7uopou12qiwvj4ralc',
#  '3wxe',
#  '3½',
#  '40',
#  '400',
#  '4000',
#  '401',
#  '401k',
#  '407',
#  '40s',
#  '41',
#  '410558250946075',
#  '411',
#  '413',
#  '41s',
#  '42',
#  '4202',
#  '422',
#  '425',
#  '426',
#  '427',
#  '428',
#  '429',
#  '42nd',
#  '43',
#  '430',
#  '435',
#  '439',
#  '43rd',
#  '44',
#  '441',
#  '443',
#  '445',
#  '449',
#  '4490',
#  '44th',
#  '45',
#  '450',
#  '454',
#  '455',
#  '458',
#  '459',
#  '45k',
#  '45th',
#  '46',
#  '46127',
#  '465',
#  '467',
#  '46th',
#  '47',
#  '470',
#  '472',
#  '47246',
#  '475',
#  '478',
#  '47percent',
#  '48',
#  '4800',
#  '481',
#  '484',
#  '486',
#  '4869',
#  '48th',
#  '49',
#  '491',
#  '492',
#  '496',
#  '4962ynktnabk3',
#  '497',
#  '498',
#  '499',
#  '49ers',
#  '49th',
#  '4am',
#  '4drwnpkfz9',
#  '4ixxpeqbc3ehfxjx2bwbupycgbomtvtjdhltv5p',
#  '4k',
#  '4pm',
#  '4th',
#  '4xn55gqy',
#  '4½',
#  '50',
#  '500',
#  '5000',
#  '501',
#  '501st',
#  '502',
#  '505',
#  '507',
#  '50k',
#  '50m',
#  '50s',
#  '50th',
#  '51',
#  '5103',
#  '511',
#  '512',
#  '516',
#  '51st',
#  '52',
#  '520',
#  '521',
#  '526',
#  '52s',
#  '53',
#  '530',
#  '531',
#  '535',
#  '536',
#  '538',
#  '539',
#  '53rd',
#  '54',
#  '542',
#  '543',
#  '55',
#  '550',
#  '559',
#  '56',
#  '560',
#  '562',
#  '566',
#  '568',
#  '56mm',
#  '57',
#  '571',
#  '573',
#  '575',
#  '578',
#  '58',
#  '580',
#  '584',
#  '589',
#  '59',
#  '590',
#  '594',
#  '595',
#  '596',
#  '5b',
#  '5billion',
#  '5cm',
#  '5d',
#  '5e09',
#  '5etq4j3ejpqrtn1znyzpbykr19',
#  '5f',
#  '5hi14dteo8',
#  '5lncbkedqrvkahoasaavnuor',
#  '5off',
#  '5paoy5l4isnzd8z0mnglwoglmq3ignjayuzvjrhdb5rvqec6qx4r4e1xjymjsxdz',
#  '5q4l04b5pm',
#  '5rm8gfvsr8',
#  '5th',
#  '5xht',
#  '5yotsyhumk91gdfgkofuc',
#  '60',
#  '600',
#  '6000',
#  '6001',
#  '603',
#  '609',
#  '60cm',
#  '60s',
#  '61',
#  '610',
#  '6102',
#  '6116',
#  '616',
#  '62',
#  '620',
#  '626',
#  '63',
#  '636',
#  '64',
#  '640',
#  '641',
#  '641a',
#  '642',
#  '643',
#  '646',
#  '65',
#  '650',
#  '650k',
#  '66',
#  '660',
#  '666',
#  '668',
#  '669',
#  '67',
#  '675',
#  '68',
#  '6801',
#  '681',
#  '682',
#  '683',
#  '69',
#  '691',
#  '694',
#  '695',
#  '699',
#  '69th',
#  '6extebxtawh4hagu',
#  '6hrytzibdjk4jdbh6jax',
#  '6k',
#  '6m',
#  '6pm',
#  '6th',
#  '6z0bjkr23s',
#  '70',
#  '700',
#  '7000',
#  '702',
#  '70530',
#  '70s',
#  '70th',
#  '71',
#  '710',
#  '712',
#  '714',
#  '716',
#  '719',
#  '71e',
#  '72',
#  '727',
#  '728',
#  '73',
#  '730',
#  '7323',
#  '732e',
#  '733',
#  '736859547360474',
#  '74',
#  '740',
#  '746',
#  '747',
#  '7494',
#  '75',
#  '750',
#  '75094',
#  '756',
#  '757',
#  '76',
#  '760',
#  '7615',
#  '762',
#  '763',
#  '76ers',
#  '76th',
#  '77',
#  '770',
#  '7764473984',
#  '777',
#  '777099609375',
#  '779',
#  '77th',
#  '78',
#  '780',
#  '781',
#  '783',
#  '785',
#  '788',
#  '79',
#  '791',
#  '7943',
#  '795',
#  '796',
#  '797788639014989826',
#  '7a6tmuh7dfmlhcqw8bf5veyag3rpkhgcm7utdb6k',
#  '7b',
#  '7b2ybrrywhqmgfj',
#  '7d',
#  '7m',
#  '7m55s',
#  '7th',
#  '80',
#  '800',
#  '804',
#  '807',
#  '809',
#  '80s',
#  '81',
#  '812',
#  '816',
#  '82',
#  '822',
#  '824',
#  '825s',
#  '826',
#  '827s',
#  '83',
#  '837',
#  '84',
#  '840',
#  '845',
#  '846',
#  '8462852',
#  '8463',
#  '847',
#  '85',
#  '854',
#  '8559',
#  '859',
#  '86',
#  '864',
#  '865',
#  '866',
#  '867',
#  '8673',
#  '86b',
#  '87',
#  '870',
#  '872',
#  '875',
#  '878',
#  '88',
#  '880',
#  '881',
#  '89',
#  '891',
#  '8932',
#  '8968',
#  '8days',
#  '8dba',
#  '8f4igwukduq',
#  '8hqgzh',
#  '8k',
#  '8m55s',
#  '8pm',
#  '8qbbibv0onfy',
#  '8quukvcctb1',
#  '8s5s5',
#  '8th',
#  '8wu9svqzw1du6pgbb30x',
#  '90',
#  '900',
#  '900m',
#  '908',
#  '90s',
#  '91',
#  '911',
#  '913',
#  ...]

# %%
model=PassiveAggressiveClassifier(max_iter=80)

# %%
model.fit(tfidf_train,y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=80)

# %%
y_pred=model.predict(tfidf_test)
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9123914759273876
